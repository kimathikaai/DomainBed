# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from domainbed.lib.misc import get_tsne_df

# %%
df_erm = get_tsne_df('tsne_data_erm.pickle')
df_xdom = get_tsne_df('tsne_data_xdom.pickle')
# Out:
# /Users/saadhossain/miniconda3/envs/torch/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/saadhossain/miniconda3/envs/torch/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /Users/saadhossain/miniconda3/envs/torch/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/saadhossain/miniconda3/envs/torch/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
df = df_erm

all_colours = list(mcolors.TABLEAU_COLORS.keys())

fig = plt.figure()
ax = plt.subplot(111)

for i, label in enumerate(df['class'].unique()):
    ax.scatter(x=np.array(list(df[df['class']==label]['tsne_embeddings']))[:, 0].tolist(), 
                y=np.array(list(df[df['class']==label]['tsne_embeddings']))[:, 1].tolist(), 
                s = 2, c = all_colours[i], label=label)

plt.axis('off')
plt.title('ERM')
# Out:
# Text(0.5, 1.0, 'ERM')

# %%
df = df_xdom

all_colours = list(mcolors.TABLEAU_COLORS.keys())

fig = plt.figure()
ax = plt.subplot(111)

for i, label in enumerate(df['class'].unique()):
    ax.scatter(x=np.array(list(df[df['class']==label]['tsne_embeddings']))[:, 0].tolist(), 
                y=np.array(list(df[df['class']==label]['tsne_embeddings']))[:, 1].tolist(), 
                s = 2, c = all_colours[i], label=label)

plt.axis('off')
plt.title('XDom')
# Out:
# Text(0.5, 1.0, 'XDom')
